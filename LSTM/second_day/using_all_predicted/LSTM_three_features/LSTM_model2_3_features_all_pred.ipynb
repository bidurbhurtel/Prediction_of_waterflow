# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
#import data
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
#define train and label column
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Precipitation(t+1)","Temperature(t+1)","Outflow(t+1)"]

# %%
#filter the columns
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Precipitation(t+%d)' %(i+1)] = new_df['Precipitation'].shift(-(i+1))
        df['Temperature(t+%d)' %(i+1)] = new_df['Temperature'].shift(-(i+1))        
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
lag_df
# Out:
#         Precipitation  Temperature  ...  Temperature(t+2)  Outflow(t+2)
# 0                 0.0      102.992  ...            92.588           5.0
# 1                 0.0       97.790  ...            87.404           5.0
# 2                 0.0       92.588  ...            85.172           5.0
# 3                 0.0       87.404  ...            82.940           5.0
# 4                 0.0       85.172  ...            80.708           5.0
# ...               ...          ...  ...               ...           ...
# 185537            0.0       50.054  ...            54.284          30.0
# 185538            0.0       52.880  ...            55.670          29.0
# 185539            0.0       54.284  ...            57.074          29.0
# 185540            0.0       55.670  ...            57.056          31.0
# 185541            0.0       57.074  ...            57.020          38.0
#
# [185542 rows x 9 columns]

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 3)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 3)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(3, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []

def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration(1,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 47s 8ms/step - loss: 0.0025 - val_loss: 5.1935e-04
# Epoch 2/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.8269e-04 - val_loss: 1.6122e-04
# Epoch 3/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.1746e-04 - val_loss: 1.6195e-04
# Epoch 4/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.9433e-04 - val_loss: 1.6386e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7460e-04 - val_loss: 2.5695e-04
# Epoch 6/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.4945e-04 - val_loss: 4.5650e-04
# Epoch 7/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.4480e-04 - val_loss: 3.9737e-04
# Epoch 8/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.2942e-04 - val_loss: 4.2308e-04
# Epoch 9/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.3034e-04 - val_loss: 5.7860e-04
# Epoch 10/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.2322e-04 - val_loss: 3.8905e-04
# --------------------------
#
# Starting time: 1612993210.8954077
# Completing time: 1612993595.282522
# It took -6.4064519047737125 minutes to train the model for 1 iterations

# %%
#prediction for X_Train values which has to be used to predict another day output
y_train_predict = model.predict(X_Train)

# %%
#define train and label column for day 2
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Outflow(t+2)"]

# %%
#Building timeseries for day 2
time_steps = 18
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 3)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 3)

# %%
#preparing timeseries for day2 data
train_input_size_0 = X_Train.shape[0]
test_input_size_0 = X_Test.shape[0]
input_size_2 = X_Train.shape[2]
output_size_0 = Y_Train.shape[0]
output_size_1 = Y_Train.shape[1]
X_Train1 = np.zeros((train_input_size_0, time_steps+1, input_size_2))
X_Test1 = np.zeros((test_input_size_0, time_steps+1, input_size_2))

#replacing last value of each timeseries data with the predicted value
len_data = len(X_Train1)
for i in range (len_data):
    #reshaping y_train_predict to make both values under concatenation of same shape 
    X_Train1[i] = np.concatenate((X_Train[i], y_train_predict[i].reshape(1,3)), axis=0) 
len_data_test = len(X_Test)
for i in range (len_data_test):
    X_Test1[i] = np.concatenate((X_Test[i],predicted_y_values[i].reshape(1,3)), axis=0)

# %%
#Build Model for day 2
def make_model1(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter1 = []
train_loss_over_epoch1 = []
val_loss_over_epoch1 = []
predicted_y_values1_unnors = []
models = []

def run_iteration_model_2(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model1 = make_model1(X_Train1)
        #plot_model(model, show_shapes=True)
        model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model1.fit(X_Train1, Y_Train, epochs=epochs,
                       validation_data=(X_Test1, Y_Test))
        train_loss_over_epoch1.append(history.history['loss'])
        val_loss_over_epoch1.append(history.history['val_loss'])
        predicted_y_values1 = model1.predict(X_Test1)
        predicted_y_values1_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values1)
        mse_for_iter1.append(mean_squared_error(predicted_y_values1_unnor, Y_test_actual))
        predicted_y_values1_unnors.append(predicted_y_values1_unnor)
        models.append(model1)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values1, predicted_y_values1_unnor, model1

predicted_y_values1, predicted_y_values1_unnor, model1 = run_iteration_model_2(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0022 - val_loss: 2.7381e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1859e-04 - val_loss: 3.2202e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.5143e-04 - val_loss: 3.8700e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2377e-04 - val_loss: 5.0492e-04
# Epoch 5/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.1302e-04 - val_loss: 3.9864e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8754e-04 - val_loss: 8.8566e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8378e-04 - val_loss: 4.7659e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8632e-04 - val_loss: 6.0415e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6616e-04 - val_loss: 5.8763e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6669e-04 - val_loss: 7.9880e-04
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0026 - val_loss: 3.2948e-04
# Epoch 2/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 3.1064e-04 - val_loss: 2.0688e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6750e-04 - val_loss: 2.6441e-04
# Epoch 4/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.3359e-04 - val_loss: 4.6827e-04
# Epoch 5/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.0855e-04 - val_loss: 3.9570e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9271e-04 - val_loss: 4.3844e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8361e-04 - val_loss: 3.7651e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7820e-04 - val_loss: 4.7154e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.5927e-04 - val_loss: 4.8413e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.5975e-04 - val_loss: 5.8350e-04
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0023 - val_loss: 3.1729e-04
# Epoch 2/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 3.2441e-04 - val_loss: 3.5300e-04
# Epoch 3/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.5119e-04 - val_loss: 4.6837e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3523e-04 - val_loss: 4.7524e-04
# Epoch 5/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.1798e-04 - val_loss: 4.3453e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0560e-04 - val_loss: 3.4745e-04
# Epoch 7/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.9261e-04 - val_loss: 4.3060e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7956e-04 - val_loss: 3.7600e-04
# Epoch 9/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.7537e-04 - val_loss: 5.4965e-04
# Epoch 10/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.7446e-04 - val_loss: 4.8806e-04
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 40s 8ms/step - loss: 0.0024 - val_loss: 2.9442e-04
# Epoch 2/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 3.0985e-04 - val_loss: 3.2276e-04
# Epoch 3/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.4856e-04 - val_loss: 4.8333e-04
# Epoch 4/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 2.2400e-04 - val_loss: 4.1625e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0114e-04 - val_loss: 5.4988e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0490e-04 - val_loss: 4.2470e-04
# Epoch 7/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.9176e-04 - val_loss: 5.1765e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8963e-04 - val_loss: 4.7111e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7916e-04 - val_loss: 5.6239e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7617e-04 - val_loss: 5.7795e-04
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0028 - val_loss: 2.5751e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.9277e-04 - val_loss: 3.3320e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3403e-04 - val_loss: 5.2407e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2274e-04 - val_loss: 8.3544e-04
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.0682e-04 - val_loss: 5.3324e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9283e-04 - val_loss: 6.1700e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8141e-04 - val_loss: 5.4174e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7543e-04 - val_loss: 7.0513e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7031e-04 - val_loss: 7.4159e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6377e-04 - val_loss: 7.8540e-04
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0026 - val_loss: 2.8285e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1394e-04 - val_loss: 2.4334e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.7379e-04 - val_loss: 2.2428e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3092e-04 - val_loss: 4.7598e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1216e-04 - val_loss: 4.5762e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9262e-04 - val_loss: 3.9022e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8679e-04 - val_loss: 5.3777e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7711e-04 - val_loss: 3.9963e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7284e-04 - val_loss: 5.4301e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6456e-04 - val_loss: 4.3403e-04
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 2.5917e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1134e-04 - val_loss: 2.0003e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6325e-04 - val_loss: 3.2154e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3713e-04 - val_loss: 3.9236e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1302e-04 - val_loss: 4.0882e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9265e-04 - val_loss: 4.7533e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8652e-04 - val_loss: 4.5200e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7732e-04 - val_loss: 5.5683e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.6950e-04 - val_loss: 7.1928e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6873e-04 - val_loss: 5.8232e-04
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 2.4531e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.0610e-04 - val_loss: 2.5580e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6462e-04 - val_loss: 2.0335e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3407e-04 - val_loss: 3.2738e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1433e-04 - val_loss: 3.3571e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9411e-04 - val_loss: 4.0850e-04
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.8254e-04 - val_loss: 5.7517e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7837e-04 - val_loss: 6.0296e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7083e-04 - val_loss: 5.1288e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7389e-04 - val_loss: 6.6977e-04
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0026 - val_loss: 2.7808e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1705e-04 - val_loss: 2.8583e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.5803e-04 - val_loss: 3.0763e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3236e-04 - val_loss: 3.0188e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0770e-04 - val_loss: 4.6555e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9972e-04 - val_loss: 4.3778e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8465e-04 - val_loss: 4.8238e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7167e-04 - val_loss: 5.2623e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6596e-04 - val_loss: 5.1149e-04
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.7628e-04 - val_loss: 6.2401e-04
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0026 - val_loss: 5.0070e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.3754e-04 - val_loss: 2.3819e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6993e-04 - val_loss: 2.0249e-04
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.4040e-04 - val_loss: 2.5596e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0952e-04 - val_loss: 3.6678e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9750e-04 - val_loss: 3.7564e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9971e-04 - val_loss: 5.0700e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8743e-04 - val_loss: 4.7178e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7887e-04 - val_loss: 3.8931e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7000e-04 - val_loss: 3.4392e-04
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0024 - val_loss: 2.6506e-04
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.3740e-04 - val_loss: 2.2371e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6789e-04 - val_loss: 2.6916e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2604e-04 - val_loss: 5.4727e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1644e-04 - val_loss: 3.8878e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1149e-04 - val_loss: 3.9774e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8993e-04 - val_loss: 4.8065e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8229e-04 - val_loss: 4.9374e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7396e-04 - val_loss: 4.8834e-04
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.6808e-04 - val_loss: 4.1811e-04
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0026 - val_loss: 2.6655e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1917e-04 - val_loss: 3.3183e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6052e-04 - val_loss: 2.6673e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3499e-04 - val_loss: 2.3435e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2674e-04 - val_loss: 2.0693e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9812e-04 - val_loss: 2.7567e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9403e-04 - val_loss: 2.7079e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8313e-04 - val_loss: 2.4627e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7474e-04 - val_loss: 3.5788e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7292e-04 - val_loss: 4.8087e-04
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 2.6126e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1122e-04 - val_loss: 2.1965e-04
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6913e-04 - val_loss: 2.7638e-04
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.3552e-04 - val_loss: 2.1168e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1689e-04 - val_loss: 2.2182e-04
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.1191e-04 - val_loss: 2.2001e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8853e-04 - val_loss: 3.7482e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7475e-04 - val_loss: 3.5021e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6714e-04 - val_loss: 4.6456e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7074e-04 - val_loss: 4.9203e-04
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 3.2062e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.1522e-04 - val_loss: 2.6280e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.4048e-04 - val_loss: 2.7551e-04
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.2449e-04 - val_loss: 7.4601e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0194e-04 - val_loss: 7.9336e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9613e-04 - val_loss: 7.0977e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8337e-04 - val_loss: 7.0053e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7691e-04 - val_loss: 8.6294e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.7313e-04 - val_loss: 7.2020e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7203e-04 - val_loss: 7.7588e-04
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 2.7976e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.2369e-04 - val_loss: 2.3041e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6606e-04 - val_loss: 2.6662e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2624e-04 - val_loss: 2.7932e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0568e-04 - val_loss: 4.2206e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0715e-04 - val_loss: 7.3229e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8942e-04 - val_loss: 4.4876e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8100e-04 - val_loss: 4.9994e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6820e-04 - val_loss: 5.1165e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6389e-04 - val_loss: 6.9605e-04
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0025 - val_loss: 2.6980e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.2684e-04 - val_loss: 2.6212e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6676e-04 - val_loss: 3.3144e-04
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.3176e-04 - val_loss: 3.8680e-04
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.0232e-04 - val_loss: 6.1405e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9688e-04 - val_loss: 4.7410e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8222e-04 - val_loss: 5.5375e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7486e-04 - val_loss: 6.2373e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.6762e-04 - val_loss: 6.6090e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7294e-04 - val_loss: 6.7158e-04
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0027 - val_loss: 3.0789e-04
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.1608e-04 - val_loss: 2.4552e-04
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.5818e-04 - val_loss: 3.8363e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2485e-04 - val_loss: 4.4717e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0180e-04 - val_loss: 3.6335e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9289e-04 - val_loss: 4.5353e-04
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.8293e-04 - val_loss: 4.6047e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8706e-04 - val_loss: 4.9918e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9372e-04 - val_loss: 5.8099e-04
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.7087e-04 - val_loss: 3.9626e-04
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 0.0025 - val_loss: 5.2372e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.6632e-04 - val_loss: 2.2445e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.7460e-04 - val_loss: 2.3575e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3406e-04 - val_loss: 3.0611e-04
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.0972e-04 - val_loss: 3.1069e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.0392e-04 - val_loss: 4.9192e-04
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9947e-04 - val_loss: 5.6557e-04
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.7964e-04 - val_loss: 4.9530e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.7333e-04 - val_loss: 5.3963e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6974e-04 - val_loss: 5.7876e-04
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0022 - val_loss: 2.8245e-04
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.1112e-04 - val_loss: 2.5107e-04
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6147e-04 - val_loss: 1.9808e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.3915e-04 - val_loss: 2.9126e-04
# Epoch 5/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.1537e-04 - val_loss: 2.7073e-04
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.9796e-04 - val_loss: 4.7780e-04
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.8420e-04 - val_loss: 3.5883e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.7078e-04 - val_loss: 5.2217e-04
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6311e-04 - val_loss: 4.8074e-04
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.6244e-04 - val_loss: 4.6048e-04
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 0.0025 - val_loss: 3.1248e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.2854e-04 - val_loss: 1.9767e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6669e-04 - val_loss: 2.5616e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2760e-04 - val_loss: 4.6709e-04
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.0288e-04 - val_loss: 6.3047e-04
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.9551e-04 - val_loss: 6.4824e-04
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.8425e-04 - val_loss: 4.6308e-04
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.8075e-04 - val_loss: 5.5525e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.6776e-04 - val_loss: 8.6651e-04
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.6554e-04 - val_loss: 5.8948e-04
# --------------------------
#
# Starting time: 1612993608.7499897
# Completing time: 1613001201.8411038
# It took -126.55151856740316 minutes to train the model for 20 iterations

# %%
model1.save("lstm_model2_3_features_all_pred.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter1)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch1[index])
            axs[row, col].plot(val_loss_over_epoch1[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values1_unnor, 'bo', alpha=0.8)
    plt.plot(Y_test_actual, 'ro', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter1
# Out:
# [96.77905256070919,
#  125.23631198782374,
#  69.08300753865716,
#  110.41821424430975,
#  77.91039473101146,
#  68.62451221814506,
#  141.96781173918777,
#  103.28414921708956,
#  86.23593409588977,
#  118.6177357069638,
#  70.2891332390087,
#  116.50185722169878,
#  67.86318150302922,
#  87.75746569146797,
#  73.24730245173642,
#  78.93901824712434,
#  59.13889471204115,
#  76.22325112206101,
#  81.42401487082317,
#  97.63038433395059]

# %%
print(np.mean(mse_for_iter1))
# Out:
# 90.35858137163643

# %%
plot_model(model1, show_shapes=True)
